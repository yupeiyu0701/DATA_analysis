# %%
#软件包下载添加信任
#--trusted-host mirrors.aliyun.com
#--trusted-host pypi.tuna.tsinghua.edu.cn

# %%
#头文件 python软件库引用
import numpy as np
import warnings

from jqdatasdk import get_all_securities

warnings.filterwarnings('ignore')
import pandas as pd
import matplotlib.pyplot as plt

# %%
#聚宽api引用
import jqdatasdk
jqdatasdk.auth('13730883122','20010701@zhyZHY')
# Out:
# auth success

# %%
jqdatasdk.get_all_securities(types=['stock'],date=None)
# Out:
#             display_name  name start_date   end_date   type
# 000001.XSHE         平安银行  PAYH 1991-04-03 2200-01-01  stock
# 000002.XSHE          万科A   WKA 1991-01-29 2200-01-01  stock
# 000004.XSHE         国华网安  GHWA 1990-12-01 2200-01-01  stock
# 000005.XSHE         ST星源  STXY 1990-12-10 2024-04-25  stock
# 000006.XSHE         深振业A  SZYA 1992-04-27 2200-01-01  stock
# ...                  ...   ...        ...        ...    ...
# 688799.XSHG         华纳药厂  HNYC 2021-07-13 2200-01-01  stock
# 688800.XSHG          瑞可达   RKD 2021-07-22 2200-01-01  stock
# 688819.XSHG         天能股份  TNGF 2021-01-18 2200-01-01  stock
# 688981.XSHG         中芯国际  ZXGJ 2020-07-16 2200-01-01  stock
# 689009.XSHG         九号公司  JHGS 2020-10-29 2200-01-01  stock
#
# [5397 rows x 5 columns]

# %%
jqdatasdk.get_billboard_list(stock_list=None,start_date='2023-11-02',end_date='2024-11-08')
# Out:
#                code         day direction  rank  abnormal_code  \
# 0       688778.XSHG  2024-11-08      SELL     4         106023
# 1       688778.XSHG  2024-11-08      SELL     1         106023
# 2       688778.XSHG  2024-11-08      SELL     2         106023
# 3       688778.XSHG  2024-11-08      SELL     3         106023
# 4       688778.XSHG  2024-11-08      SELL     5         106023
# ...             ...         ...       ...   ...            ...
# 199140  000615.XSHE  2023-11-02      SELL     4         106010
# 199141  000615.XSHE  2023-11-02      SELL     5         106010
# 199142  000615.XSHE  2023-11-02       ALL     0         106010
# 199143  000615.XSHE  2023-11-02      SELL     2         106010
# 199144  000615.XSHE  2023-11-02      SELL     1         106010
#
#                                   abnormal_name         sales_depart_name  \
# 0          有价格涨跌幅限制的连续3个交易日内收盘价格涨幅偏离值累计达到30%的证券     招商证券股份有限公司福州六一中路证券营业部
# ...
